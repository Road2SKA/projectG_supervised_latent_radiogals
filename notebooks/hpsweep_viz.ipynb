# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

CSV = '../outputs/hyperparameter_tuning/sweep_results.csv'
METRIC = 'protege_proj_recall_auc'  # change to: lr_f1_macro,lr_auc_macro, val_friend_loss_best, protege_proj_recall_auc

df = pd.read_csv(CSV)
df = df[df['status'] == 'complete'].copy()
print(f"{len(df)} complete runs   |   metric: {METRIC}")
df[['run_name', 'projection_dim', 'weight_decay', 'lr_schedule', 'augmentation', 'vicreg', METRIC]].sort_values(METRIC, ascending=False).head(10)
# Out:
# 42 complete runs   |   metric: protege_proj_recall_auc
#                                       run_name  projection_dim  weight_decay  \
# 2           pd128_wd1e-3_lrconst_20260729_1621             128        0.0010
# 3            pd128_wd1e-3_lrstep_20260729_1622             128        0.0010
# 6   pd128_qext_v1_wd1e-3_lrconst_20260730_1317             128        0.0010
# 7    pd128_qext_v1_wd1e-3_lrstep_20260730_1317             128        0.0010
# 14  pd128_qsmp_v1_wd1e-3_lrconst_20260730_1317             128        0.0010
# 31   pd512_qext_v1_wd1e-3_lrstep_20260730_1319             512        0.0010
# 29           pd512_wd1e-4_lrstep_20260729_1624             512        0.0001
# 15   pd128_qsmp_v1_wd1e-3_lrstep_20260730_1317             128        0.0010
# 30  pd512_qext_v1_wd1e-3_lrconst_20260730_1319             512        0.0010
# 4           pd128_wd1e-4_lrconst_20260729_1621             128        0.0001
#
#    lr_schedule augmentation vicreg  protege_proj_recall_auc
# 2     constant    quart_ext    off                 0.658374
# 3         step    quart_ext    off                 0.656056
# 6     constant    quart_ext     on                 0.654089
# 7         step    quart_ext     on                 0.651459
# 14    constant        quart     on                 0.650701
# 31        step    quart_ext     on                 0.650334
# 29        step    quart_ext    off                 0.650333
# 15        step        quart     on                 0.650066
# 30    constant    quart_ext     on                 0.649275
# 4     constant    quart_ext    off                 0.645677

# %%
# Heatmap: weight_decay x projection_dim, faceted by augmentation x vicreg
augs = sorted(df['augmentation'].dropna().unique())
vics = sorted(df['vicreg'].dropna().unique())

vmin, vmax = df[METRIC].min(), df[METRIC].max()
fig, axes = plt.subplots(len(vics), len(augs), figsize=(5 * len(augs), 4 * len(vics)), squeeze=False)

for r, vic in enumerate(vics):
    for c, aug in enumerate(augs):
        ax = axes[r][c]
        sub = df[(df.augmentation == aug) & (df.vicreg == vic)]
        if sub.empty:
            ax.set_visible(False)
            continue
        pivot = sub.pivot_table(index='weight_decay', columns='projection_dim',
                                values=METRIC, aggfunc='mean')
        sns.heatmap(pivot, ax=ax, annot=True, fmt='.3f', cmap='YlGn',
                    vmin=vmin, vmax=vmax, cbar=(c == len(augs) - 1))
        ax.set_title(f'aug={aug}  vicreg={vic}', fontsize=11)

fig.suptitle(f'{METRIC} — mean over lr_schedule', y=1.02, fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Marginal effect of each axis
axes_cols = ['projection_dim', 'weight_decay', 'lr_schedule', 'augmentation', 'vicreg']
fig, axes = plt.subplots(1, len(axes_cols), figsize=(3.5 * len(axes_cols), 4), sharey=True)

for ax, col in zip(axes, axes_cols):
    order = sorted(df[col].dropna().unique(), key=str)
    sns.stripplot(data=df, x=col, y=METRIC, ax=ax, order=order,
                  jitter=True, size=5, alpha=0.6)
    sns.pointplot(data=df, x=col, y=METRIC, ax=ax, order=order,
                  estimator='mean', color='crimson', markers='D',
                  linestyles='--', errorbar=None)
    ax.set_xlabel(col, fontsize=10)
    ax.tick_params(axis='x', labelsize=9)

axes[0].set_ylabel(METRIC)
fig.suptitle('Marginal effect of each hyperparameter', fontsize=13)
plt.tight_layout()
plt.show()

# %%
# Full ranked table
cols = ['run_name', 'projection_dim', 'weight_decay', 'lr_schedule',
        'augmentation', 'vicreg', 'lr_f1_macro', 'lr_auc_macro',
         'protege_proj_recall_auc', 'val_friend_loss_best', 'train_loss_best',
         'train_loss_best_epoch', 'train_loss_final']
available = [c for c in cols if c in df.columns]
df[available].sort_values(METRIC, ascending=False).style \
    .background_gradient(subset=[METRIC], cmap='YlGn') \
    .format({c: '{:.4f}' for c in available if df[c].dtype == float})
# Out:
# <style type="text/css">
# #T_2e9ee_row0_col9 {
#   background-color: #004529;
#   color: #f1f1f1;
# }
# #T_2e9ee_row1_col9 {
#   background-color: #004a2b;
#   color: #f1f1f1;
# }
# #T_2e9ee_row2_col9 {
#   background-color: #00502d;
#   color: #f1f1f1;
# }
# #T_2e9ee_row3_col9 {
#   background-color: #005730;
#   color: #f1f1f1;
# }
# #T_2e9ee_row4_col9 {
#   background-color: #005931;
#   color: #f1f1f1;
# }
# #T_2e9ee_row5_col9, #T_2e9ee_row6_col9 {
#   background-color: #005a31;
#   color: #f1f1f1;
# }
# #T_2e9ee_row7_col9 {
#   background-color: #005b32;
#   color: #f1f1f1;
# }
# #T_2e9ee_row8_col9 {
#   background-color: #005d33;
#   color: #f1f1f1;
# }
# #T_2e9ee_row9_col9, #T_2e9ee_row10_col9 {
#   background-color: #006737;
#   color: #f1f1f1;
# }
# #T_2e9ee_row11_col9, #T_2e9ee_row12_col9 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_2e9ee_row13_col9 {
#   background-color: #016937;
#   color: #f1f1f1;
# }
# #T_2e9ee_row14_col9 {
#   background-color: #036b38;
#   color: #f1f1f1;
# }
# #T_2e9ee_row15_col9 {
#   background-color: #0a703a;
#   color: #f1f1f1;
# }
# #T_2e9ee_row16_col9 {
#   background-color: #11753d;
#   color: #f1f1f1;
# }
# #T_2e9ee_row17_col9 {
#   background-color: #12763d;
#   color: #f1f1f1;
# }
# #T_2e9ee_row18_col9 {
#   background-color: #13773d;
#   color: #f1f1f1;
# }
# #T_2e9ee_row19_col9 {
#   background-color: #1d7f41;
#   color: #f1f1f1;
# }
# #T_2e9ee_row20_col9 {
#   background-color: #248644;
#   color: #f1f1f1;
# }
# #T_2e9ee_row21_col9, #T_2e9ee_row22_col9 {
#   background-color: #2a8d49;
#   color: #f1f1f1;
# }
# #T_2e9ee_row23_col9, #T_2e9ee_row24_col9 {
#   background-color: #2d914b;
#   color: #f1f1f1;
# }
# #T_2e9ee_row25_col9 {
#   background-color: #339951;
#   color: #f1f1f1;
# }
# #T_2e9ee_row26_col9 {
#   background-color: #3fa85b;
#   color: #f1f1f1;
# }
# #T_2e9ee_row27_col9 {
#   background-color: #49af61;
#   color: #f1f1f1;
# }
# #T_2e9ee_row28_col9 {
#   background-color: #75c578;
#   color: #000000;
# }
# #T_2e9ee_row29_col9 {
#   background-color: #8dcf81;
#   color: #000000;
# }
# #T_2e9ee_row30_col9 {
#   background-color: #9fd788;
#   color: #000000;
# }
# #T_2e9ee_row31_col9 {
#   background-color: #e8f6ae;
#   color: #000000;
# }
# #T_2e9ee_row32_col9 {
#   background-color: #e9f6af;
#   color: #000000;
# }
# #T_2e9ee_row33_col9 {
#   background-color: #edf8b2;
#   color: #000000;
# }
# #T_2e9ee_row34_col9, #T_2e9ee_row35_col9 {
#   background-color: #f1fab5;
#   color: #000000;
# }
# #T_2e9ee_row36_col9 {
#   background-color: #f2fab5;
#   color: #000000;
# }
# #T_2e9ee_row37_col9 {
#   background-color: #f4fbb7;
#   color: #000000;
# }
# #T_2e9ee_row38_col9 {
#   background-color: #f9fdc5;
#   color: #000000;
# }
# #T_2e9ee_row39_col9 {
#   background-color: #f9fdc7;
#   color: #000000;
# }
# #T_2e9ee_row40_col9 {
#   background-color: #ffffe4;
#   color: #000000;
# }
# #T_2e9ee_row41_col9 {
#   background-color: #ffffe5;
#   color: #000000;
# }
# </style>
# <table id="T_2e9ee">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2e9ee_level0_col0" class="col_heading level0 col0" >run_name</th>
#       <th id="T_2e9ee_level0_col1" class="col_heading level0 col1" >projection_dim</th>
#       <th id="T_2e9ee_level0_col2" class="col_heading level0 col2" >weight_decay</th>
#       <th id="T_2e9ee_level0_col3" class="col_heading level0 col3" >lr_schedule</th>
#       <th id="T_2e9ee_level0_col4" class="col_heading level0 col4" >augmentation</th>
#       <th id="T_2e9ee_level0_col5" class="col_heading level0 col5" >vicreg</th>
#       <th id="T_2e9ee_level0_col6" class="col_heading level0 col6" >lr_f1_macro</th>
#       <th id="T_2e9ee_level0_col7" class="col_heading level0 col7" >lr_auc_macro</th>
#       <th id="T_2e9ee_level0_col8" class="col_heading level0 col8" >val_friend_loss_best</th>
#       <th id="T_2e9ee_level0_col9" class="col_heading level0 col9" >protege_proj_recall_auc</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2e9ee_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_2e9ee_row0_col0" class="data row0 col0" >pd128_wd1e-3_lrconst_20260729_1621</td>
#       <td id="T_2e9ee_row0_col1" class="data row0 col1" >128</td>
#       <td id="T_2e9ee_row0_col2" class="data row0 col2" >0.0010</td>
#       <td id="T_2e9ee_row0_col3" class="data row0 col3" >constant</td>
#       <td id="T_2e9ee_row0_col4" class="data row0 col4" >quart_ext</td>
#       <td id="T_2e9ee_row0_col5" class="data row0 col5" >off</td>
#       <td id="T_2e9ee_row0_col6" class="data row0 col6" >0.6950</td>
#       <td id="T_2e9ee_row0_col7" class="data row0 col7" >0.9430</td>
#       <td id="T_2e9ee_row0_col8" class="data row0 col8" >nan</td>
#       <td id="T_2e9ee_row0_col9" class="data row0 col9" >0.6584</td>
#     </tr>
#     <tr>
#       <th id="T_2e9ee_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_2e9ee_row1_col0" class="data row1 col0" >pd128_wd1e-3_lrstep_20260729_1622</td>
#       <td id="T_2e9ee_row1_col1" class="data row1 col1" >128</td>
#       <td id="T_2e9ee_row1_col2" class="data row1 col2" >0.0010</td>
#       <td id="T_2e9ee_row1_col3" class="data row1 col3" >step</td>
#       <td id="T_2e9ee_row1_col4" class="data row1 col4" >quart_ext</td>
#       <td id="T_2e9ee_row1_col5" class="data row1 col5" >off</td>
#       <td id="T_2e9ee_row1_col6" class="data row1 col6" >0.6871</td>
#       <td id="T_2e9ee_row1_col7" class="data row1 col7" >0.9415</td>
#       <td id="T_2e9ee_row1_col8" class="data row1 col8" >nan</td>
#       <td id="T_2e9ee_row1_col9" class="data row1 col9" >0.6561</td>
#     </tr>
#     <tr>
#       <th id="T_2e9ee_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_2e9ee_row2_col0" class="data row2 col0" >pd128_qext_v1_wd1e-3_lrconst_20260730_1317</td>
#       <td id="T_2e9ee_row2_col1" class="data row2 col1" >128</td>
#       <td id="T_2e9ee_row2_col2" class="data row2 col2" >0.0010</td>
#       <td id="T_2e9ee_row2_col3" class="data row2 col3" >constant</td>
#       <td id="T_2e9ee_row2_col4" class="data row2 col4" >quart_ext</td>
#       <td id="T_2e9ee_row2_col5" class="data row2 col5" >on</td>
#       <td id="T_2e9ee_row2_col6" class="data row2 col6" >0.7096</td>
#       <td id="T_2e9ee_row2_col7" class="data row2 col7" >0.9423</td>
#       <td id="T_2e9ee_row2_col8" class="data row2 col8" >nan</td>
#       <td id="T_2e9ee_row2_col9" class="data row2 col9" >0.6541</td>
#     </tr>
#     <tr>
#       <th id="T_2e9ee_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_2e9ee_row3_col0" class="data row3 col0" >pd128_qext_v1_wd1e-3_lrstep_20260730_1317</td>
#       <td id="T_2e9ee_row3_col1" class="data row3 col1" >128</td>
#       <td id="T_2e9ee_row3_col2" class="data row3 col2" >0.0010</td>
#       <td id="T_2e9ee_row3_col3" class="data row3 col3" >step</td>
#       <td id="T_2e9ee_row3_col4" class="data row3 col4" >quart_ext</td>
#       <td id="T_2e9ee_row3_col5" class="data row3 col5" >on</td>
#       <td id="T_2e9ee_row3_col6" class="data row3 col6" >0.7075</td>
#       <td id="T_2e9ee_row3_col7" class="data row3 col7" >0.9413</td>
#       <td id="T_2e9ee_row3_col8" class="data row3 col8" >nan</td>
#       <td id="T_2e9ee_row3_col9" class="data row3 col9" >0.6515</td>
#     </tr>
#     <tr>
#       <th id="T_2e9ee_level0_row4" class="row_heading level0 row4" >14</th>
#       <td id="T_2e9ee_row4_col0" class="data row4 col0" >pd128_qsmp_v1_wd1e-3_lrconst_20260730_1317</td>
#       <td id="T_2e9ee_row4_col1" class="data row4 col1" >128</td>
#       <td id="T_2e9ee_row4_col2" class="data row4 col2" >0.0010</td>
#       <td id="T_2e9ee_row4_col3" class="data row4 col3" >constant</td>
#       <td id="T_2e9ee_row4_col4" class="data row4 col4" >quart</td>
#       <td id="T_2e9ee_row4_col5" class="data row4 col5" >on</td>
#       <td id="T_2e9ee_row4_col6" class="data row4 col6" >0.6373</td>
#       <td id="T_2e9ee_row4_col7" class="data row4 col7" >0.9163</td>
#       <td id="T_2e9ee_row4_col8" class="data row4 col8" >nan</td>
#       <td id="T_2e9ee_row4_col9" class="data row4 col9" >0.6507</td>
#     </tr>
#     <tr>
#       <th id="T_2e9ee_level0_row5" class="row_heading level0 row5" >31</th>
#       <td id="T_2e9ee_row5_col0" class="data row5 col0" >pd512_qext_v1_wd1e-3_lrstep_20260730_1319</td>
#       <td id="T_2e9ee_row5_col1" class="data row5 col1" >512</td>
#       <t
